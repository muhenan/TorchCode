# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/solutions/03_linear_solution.ipynb)
#
# # 🟡 Solution: Simple Linear Layer
#
# Reference solution for a fully-connected linear layer: **y = xW^T + b**

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass

# %%
import torch
import math
# Out:
# /usr/local/lib/python3.11/site-packages/torch/_subclasses/functional_tensor.py:307: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %%
# ✅ SOLUTION

class SimpleLinear:
    def __init__(self, in_features: int, out_features: int):
        self.weight = torch.randn(out_features, in_features) * (1 / math.sqrt(in_features))
        self.weight.requires_grad_(True)
        self.bias = torch.zeros(out_features, requires_grad=True)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return x @ self.weight.T + self.bias

# %%
out_features, in_features = 4, 8
print(torch.randn(out_features, in_features))
print(torch.randn(out_features, in_features) * (1 / math.sqrt(in_features)))
# Out:
# tensor([[-0.8692, -1.0690, -1.3092,  0.1543, -0.2602, -1.8627,  0.4021,  0.0906],
#         [ 1.3404, -0.0144,  0.2608, -1.1320,  0.5144,  0.4051,  0.4247,  0.7184],
#         [-0.1356,  0.6329,  0.9481, -1.5711,  0.3971, -0.9710,  0.0917, -1.5375],
#         [ 0.9347, -1.7224,  0.2475, -0.1079,  0.0240, -0.0966, -0.5086, -1.6990]])
# tensor([[ 0.0629,  0.7070,  0.2916,  0.2653,  0.1366, -0.2623,  1.2062, -0.6574],
#         [ 0.5797,  0.3541, -0.5422, -0.0487, -0.8130, -0.2833,  0.3769,  0.1281],
#         [-0.2278,  0.1089,  0.3214, -0.2038, -0.0091,  0.1155,  0.0808,  0.0681],
#         [-0.0137, -0.0367, -0.0105, -0.4820, -0.3600, -0.3701,  0.1460, -0.2968]])

# %%
# Verify
layer = SimpleLinear(8, 4)
print("W shape:", layer.weight.shape)
print("b shape:", layer.bias.shape)
x = torch.randn(2, 8)
print("Output shape:", layer.forward(x).shape)
# Out:
# W shape: torch.Size([4, 8])
# b shape: torch.Size([4])
# Output shape: torch.Size([2, 4])

# %%
# Run judge
from torch_judge import check
check("linear")
# Out:
# 🧪 Testing: Simple Linear Layer (Medium)
# ──────────────────────────────────────────────────
#   ✅ [1/3] Weight & bias shape (0.2ms)
#   ✅ [2/3] Forward pass (1.3ms)
#   ✅ [3/3] Gradient flow (30.4ms)
# ──────────────────────────────────────────────────
#   🎉 All 3 tests passed! (31.9ms total)
#   Progress saved. Run status() to see your dashboard.
